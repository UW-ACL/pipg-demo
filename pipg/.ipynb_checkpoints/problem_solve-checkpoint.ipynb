# %% [markdown]
# ```
#                                                ..:: NOTES ::..
#
# For sufficiently large kmax, rd2o settles to 1e-14. This maybe determined by accuracy of JuMP-ECOS solution.
# For sufficiently large kmax_nest and kmax, rd2K for admm settles at 1e-30 or epislon_nest_admm^2, whichever is larger. Whereas, rd2K for pipg+ settles at 1e-30.
#
# ```

# %% [markdown]
# \begin{align*}
# \texttt{rd2o} &= \frac{\|z-z^\star\|_2^2}{\|z^\star\|^2_2},\\
# \texttt{rd2K} &= \frac{\|Hz-g-\prod_{\mathbb{K}}\left[Hz-g\right]\|_2^2}{\|z^\star\|^2_2}.
# \end{align*}

# %% [markdown]
# ```
# PIPG+ performs *best* with
#         Q = diag( 0.5*ones(nx/2) , 2*ones(nx/2) )
#         R = diag( 0.1*ones(nu) )
# It performs *poorly* with
#         Q = diag( 0.5*ones(nx/2) , 2*ones(nx/2) )
#         R = diag( 5.0*ones(nu) )
#
# ```

# %% [markdown]
# # Oscillating Masses w/ input rate constraint

# %%
# problem definition
include("problem_data.jl");
# Out:
# WARNING: replacing module prb.
# WARNING: replacing module proj.
# WARNING: replacing module asm.

# %%
# solver functions and variable containers
include("solver_suite.jl");
# Out:
# WARNING: replacing module jump.
# WARNING: replacing module pipg.
# WARNING: replacing module rival.
# WARNING: replacing module data_record.

# %%
# JuMP
jump.solver!(:ecos,false);

# PIPG+
pipg.solver!();

# PIPG+ w/ restart
pipg.reset_var!(:plus)
pipg.solver_proxy!(pipg.z,pipg.v,pipg.w,pipg.κK,pipg.κu,pipg.κx,pipg.rd2o_restrt,
    pipg.rd2K_restrt,prb.restrt_idx)

# PIPG affine eq.
pipg.solver_eq!();

# pipg.plot_solstat();
# Out:
# ecos termination status: OPTIMAL
# PIPG+ relative distance to optimum: 7.313922304618091e-13
# PIPG+ relative distance to optimum: 7.319353903607106e-13
# PIPG eq. relative distance to optimum: 7.314028538468295e-13

# %%
# ADMM
rival.solver_admm!()
# Out:
# ADMM relative distance to optimum: 7.314065182238013e-13

# %%
# Chambolle & Pock (variable step)
rival.solver_cp!()
# Out:
# Chambolle and Pock relative distance to optimum: 7.313593624811474e-13

# %%
rival.plot_solstat();
# Q = diag(0.5,2.0)
# R = diag(5.0)

# %%
rival.plot_solstat();
# Q = diag(0.5,2.0)
# R = diag(0.1)

# %%
rival.plot_solstat();
# Q = diag(0.5,1.0)
# R = diag(0.1)

# %%
rival.plot_solstat();
# Q, R are identity
